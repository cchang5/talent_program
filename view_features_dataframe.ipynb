# %%
import features
import pandas as pd
pd.set_option('display.max_rows', 1000)

# %%
f = features.make_features()
# Out:
# SELECT DISTINCT display_name FROM streamer;
# SUCCESS
# SELECT DISTINCT display_name FROM streamer;
# SUCCESS
# Preloading timeofweek feature
# Preloading timeofday 3 bins feature
# SELECT display_name, summonerlevel FROM streamer;
# SUCCESS
# SELECT display_name, tier, rank FROM streamer;
# SUCCESS
#                     Mon       Tue       Wed       Thu       Fri       Sat  \
# Darkfirfox     1.623333  0.982639  7.539722  6.089167  5.522083  5.559861
# DrunKev        5.541528  2.302500  5.150833  4.801944  7.176667  6.570833
# iSxckAtGaming  4.281250  5.704861  4.364444  6.324722  6.656528  2.059861
# r1fts          4.040556  0.000000  0.000000  4.301944  0.000000  2.302500
# sapo_14        2.926667  1.719722  2.758889  0.646944  3.354861  0.000000
# ...                 ...       ...       ...       ...       ...       ...
# Winderz_       0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# kingKwentin    5.770000  5.314306  4.084444  7.856806  5.711389  4.364583
# ...

# %%
with pd.option_context('display.max_rows', None, 'display.max_columns', None):  # more options can be specified also
    display(f.dropna())
# Out:
#                          Mon        Tue        Wed        Thu        Fri  \
# Darkfirfox          1.623333   0.982639   7.539722   6.089167   5.522083
# DrunKev             5.541528   2.302500   5.150833   4.801944   7.176667
# iSxckAtGaming       4.281250   5.704861   4.364444   6.324722   6.656528
# r1fts               4.040556   0.000000   0.000000   4.301944   0.000000
# sapo_14             2.926667   1.719722   2.758889   0.646944   3.354861
# Unstrait            0.230139   0.000000   0.000000   0.000000   0.000000
# JDaddyMelink        6.054861   0.000000   0.000000   0.000000   0.000000
# ImMicrowaveable     0.000000   0.000000   0.000000   0.000000   0.000000
# mowglythecat        0.000000   0.000000   0.000000   0.000000   0.000000
# thisguyjon          0.000000   0.000000   0.000000   0.000000   0.588889
# tacosmth            0.000000   1.169444   0.000000   4.392361   0.420694
# filthy_francine     0.000000   2.330833   0.000000   6.600556   0.000000
# ...
